# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %% [markdown]
# # Step 1: Setting up the python application

# %%
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain import LLMChain
from langchain.chains.question_answering import load_qa_chain
from langchain_community.document_loaders import TextLoader
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
# Importing the library for OpenAI API
import openai
openai.api_base = "https://openai.vocareum.com/v1"

# Define OpenAI API key 
api_key = ""
openai.api_key = api_key
# os.environ["OPENAI_API_KEY"] = ""
# os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %% [markdown]
# # Step 2: Generating real estate listings

# %%
def generate_real_estate_listings():
    base_prompt = """
    Generate 10 real estate listings with the following format:
    - neighborhood: [Name]
    - price: [Price]
    - bedrooms: [Number of bedrooms]
    - bathrooms: [Number of bathrooms]
    - house_size: [Size in sqft]
    
    Description: [Detailed description of the property, highlighting key features such as design, energy efficiency, and the surrounding environment.]
    
    Neighborhood Description: [Brief description of the neighborhood, including nearby amenities, community vibe, and transportation options.]
    """

    all_listings = ""
    for i in range(4):  # Repeat 4 times to generate 20 listings
        user_prompt = base_prompt + f"\nStart listing batch {i+1} below:"
        
        try:
            response = openai.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a real estate agent."},
                    {"role": "user", "content": user_prompt}
                ],
                temperature=0.5,  # Adjust for creativity level
                max_tokens=1500,
            )
            
            # Extract the generated listings and append to the full list
            listings = response.choices[0].message.content
            all_listings += listings + "\n\n"

        except Exception as e:
            return f"An error occurred: {e}"

    return all_listings

# Generate and print the listings
listings = generate_real_estate_listings()
print(listings)
# Out:
# 1.
# - Neighborhood: Green Hills
# - Price: $750,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 2,500 sqft
#
# Description: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen is equipped with stainless steel appliances and quartz countertops. The master suite boasts a luxurious bathroom with a soaking tub and walk-in shower. Enjoy the spacious backyard perfect for entertaining.
#
# Neighborhood Description: Green Hills is a highly sought-after neighborhood known for its upscale shops, restaurants, and top-rated schools. Residents enjoy easy access to parks, walking trails, and convenient transportation options.
#
# 2.
# - Neighborhood: Downtown
# - Price: $1,200,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 2,000 sqft
#
# Description: Live in luxury in this sleek downtown condo with panoramic city views. The interior features designer finishes, a gourmet kitchen with high-end appliances, and a private terrace. The building offers amenities such as a rooftop pool, fitness center, and concierge services.
#
# Neighborhood Description: Downtown is the heart of the city, offering a vibrant urban lifestyle with trendy restaurants, cultural attractions, and easy access to public transportation for a convenient commute.
#
# 3.
# - Neighborhood: Belle Meade
# - Price: $1,500,000
# - Bedrooms: 5
# - Bathrooms: 4.5
# - House Size: 4,000 sqft
#
# Description: This exquisite estate in Belle Meade exudes elegance with its grand foyer, formal dining room, and custom millwork throughout. The gourmet kitchen features top-of-the-line appliances and a breakfast nook overlooking the lush backyard. The master suite includes a spa-like bathroom and a private balcony.
#
# Neighborhood Description: Belle Meade is a prestigious neighborhood known for its stately homes, tree-lined streets, and proximity to upscale shopping and dining destinations. The area offers a tranquil setting with easy access to major highways.
#
# 4.
# - Neighborhood: East Nashville
# - Price: $500,000
# - Bedrooms: 2
# - Bathrooms: 2
# - House Size: 1,200 sqft
#
# Description: Embrace the eclectic charm of East Nashville in this newly renovated bungalow. The home features an open concept living space, hardwood floors, and a gourmet kitchen with quartz countertops. Relax on the front porch or entertain in the spacious backyard.
#
# Neighborhood Description: East Nashville is a hip and diverse neighborhood known for its vibrant arts scene, unique boutiques, and locally-owned eateries. Residents enjoy a strong sense of community and easy access to parks and green spaces.
#
# 5.
# - Neighborhood: Sylvan Park
# - Price: $600,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 1,800 sqft
#
# Description: This charming cottage in Sylvan Park offers a blend of modern updates and historic character. The home features a renovated kitchen, hardwood floors, and a cozy fireplace in the living room. The fenced backyard is perfect for outdoor gatherings.
#
# Neighborhood Description: Sylvan Park is a family-friendly neighborhood with tree-lined streets, parks, and a bustling commercial district with cafes, shops, and restaurants. The area provides a laid-back atmosphere with easy access to downtown Nashville.
#
# 6.
# - Neighborhood: Germantown
# - Price: $850,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 2,300 sqft
#
# Description: Discover urban living at its finest in this contemporary townhome in Germantown. The home features a rooftop deck with skyline views, a gourmet kitchen with custom cabinetry, and a luxurious master suite with a spa-like bathroom. Enjoy the convenience of a two-car garage.
#
# Neighborhood Description: Germantown is a historic neighborhood with a mix of old-world charm and modern amenities. Residents appreciate the neighborhood's walkability, proximity to boutique shops and eateries, and easy access to green spaces and cultural venues.
#
# 7.
# - Neighborhood: 12 South
# - Price: $700,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 1,600 sqft
#
# Description: Live in the heart of the trendy 12 South neighborhood in this stylish bungalow. The home boasts a light-filled living area, a chef's kitchen with quartz countertops, and a covered porch for relaxing outdoors. The primary suite features a walk-in closet and a spa-like bathroom.
#
# Neighborhood Description: 12 South is a popular neighborhood known for its boutique shopping, artisanal eateries, and vibrant street life. Residents enjoy a sense of community, proximity to Sevier Park, and easy access to coffee shops and entertainment venues.
#
# 8.
# - Neighborhood: Hillsboro Village
# - Price: $950,000
# - Bedrooms: 4
# - Bathrooms: 3.5
# - House Size: 2,800 sqft
#
# Description: Experience upscale living in this custom-built home in Hillsboro Village. The interior showcases high-end finishes, a gourmet kitchen with a large island, and a spacious living room with a fireplace. The primary suite offers a private balcony and a luxurious en-suite bathroom.
#
# Neighborhood Description: Hillsboro Village is a vibrant neighborhood with a mix of historic charm and modern amenities. Residents appreciate the area's eclectic shops, cozy cafes, and proximity to Vanderbilt University. Easy access to major highways and public transportation make commuting a breeze.
#
# 9.
# - Neighborhood: West End
# - Price: $1,100,000
# - Bedrooms: 5
# - Bathrooms: 4
# - House Size: 3,500 sqft
#
# Description: This elegant home in West End features a grand foyer, formal dining room, and a chef's kitchen with premium appliances. The spacious family room is perfect for entertaining, while the backyard oasis offers a serene retreat. The primary suite boasts a sitting area and a spa-like bathroom.
#
# Neighborhood Description: West End is a prestigious neighborhood known for its historic homes, upscale dining options, and proximity to Centennial Park and the Parthenon. Residents enjoy a sophisticated urban lifestyle with easy access to cultural attractions and recreational activities.
#
# 10.
# - Neighborhood: Wedgewood-Houston
# - Price: $550,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 1,700 sqft
#
# Description: Modern living awaits in this sleek townhome in Wedgewood-Houston. The home features an open concept layout, designer finishes, and a private rooftop deck with stunning views of the city skyline. The primary suite includes a walk-in closet and a spa-like bathroom.
#
# Neighborhood Description: Wedgewood-Houston is a rapidly growing neighborhood with a mix of residential and commercial development. Residents enjoy a creative and diverse community, proximity to art galleries and craft breweries, and easy access to downtown Nashville and major highways.
#
# 1.
# - Neighborhood: Willow Creek
# - Price: $450,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 2,100 sqft
#
# Description: This charming home in Willow Creek features a modern open concept design with a spacious living area, gourmet kitchen, and a cozy backyard patio perfect for entertaining. Energy-efficient appliances and smart home features make this property both stylish and eco-friendly.
#
# Neighborhood Description: Willow Creek is a family-friendly neighborhood known for its top-rated schools, parks, and walking trails. Residents enjoy easy access to shopping centers, restaurants, and public transportation options.
#
# 2.
# - Neighborhood: Oak Ridge Estates
# - Price: $650,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 3,500 sqft
#
# Description: Nestled in the prestigious Oak Ridge Estates, this luxurious home boasts high-end finishes, a grand foyer, and a private backyard oasis with a pool and spa. The property also features a home office, media room, and a three-car garage.
#
# Neighborhood Description: Oak Ridge Estates offers a tranquil setting with tree-lined streets and upscale homes. The neighborhood is close to golf courses, country clubs, and upscale dining options.
#
# 3.
# - Neighborhood: Riverfront Heights
# - Price: $800,000
# - Bedrooms: 5
# - Bathrooms: 4.5
# - House Size: 4,200 sqft
#
# Description: This stunning riverfront property features panoramic views, a gourmet chef's kitchen, and a spacious master suite with a private balcony. The outdoor living space includes a deck, fire pit, and direct access to the river.
#
# Neighborhood Description: Riverfront Heights is an exclusive enclave known for its waterfront properties and upscale amenities. Residents can enjoy boating, fishing, and nearby shopping and dining options.
#
# 4.
# - Neighborhood: Mountain View Estates
# - Price: $1,200,000
# - Bedrooms: 6
# - Bathrooms: 5
# - House Size: 5,000 sqft
#
# Description: Situated in the prestigious Mountain View Estates, this custom-built home offers luxury living with high ceilings, a gourmet kitchen, and a private backyard with a pool and outdoor kitchen. The property also features a home theater and a wine cellar.
#
# Neighborhood Description: Mountain View Estates is an upscale community surrounded by scenic mountain views and lush greenery. The neighborhood is close to hiking trails, golf courses, and upscale shopping centers.
#
# 5.
# - Neighborhood: Lakeside Retreat
# - Price: $550,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 2,300 sqft
#
# Description: This lakeside retreat features a cozy cabin-style design with vaulted ceilings, a stone fireplace, and a wrap-around deck overlooking the serene lake. The property also includes a private dock for boating and fishing.
#
# Neighborhood Description: Lakeside Retreat offers a peaceful escape from the city with tranquil lake views and abundant wildlife. Residents can enjoy water activities, hiking trails, and nearby cafes and art galleries.
#
# 6.
# - Neighborhood: Sunset Ridge
# - Price: $700,000
# - Bedrooms: 4
# - Bathrooms: 3.5
# - House Size: 3,800 sqft
#
# Description: Perched on a hill in Sunset Ridge, this contemporary home features floor-to-ceiling windows, a sleek gourmet kitchen, and a spacious outdoor deck with panoramic sunset views. The property also includes a home gym and a landscaped backyard.
#
# Neighborhood Description: Sunset Ridge is a sought-after neighborhood known for its stunning sunsets and peaceful ambiance. Residents have access to hiking trails, parks, and trendy restaurants and cafes.
#
# 7.
# - Neighborhood: Pinehurst Meadows
# - Price: $480,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 2,100 sqft
#
# Description: This charming ranch-style home in Pinehurst Meadows offers single-level living with a cozy fireplace, updated kitchen, and a large backyard with a vegetable garden. The property also features a detached studio perfect for a home office or art space.
#
# Neighborhood Description: Pinehurst Meadows is a quiet neighborhood with a strong sense of community and well-maintained green spaces. Residents enjoy easy access to local markets, schools, and recreational facilities.
#
# 8.
# - Neighborhood: Harbor View
# - Price: $950,000
# - Bedrooms: 4
# - Bathrooms: 3.5
# - House Size: 3,600 sqft
#
# Description: Overlooking the harbor, this elegant home in Harbor View boasts a grand entrance, formal dining room, and a luxurious master suite with a spa-like bathroom. The property features a landscaped backyard with a built-in BBQ and fire pit.
#
# Neighborhood Description: Harbor View is a prestigious waterfront community with marinas, yacht clubs, and upscale dining options. Residents can enjoy waterfront activities, scenic views, and easy access to nearby beaches.
#
# 9.
# - Neighborhood: Maple Grove Estates
# - Price: $580,000
# - Bedrooms: 4
# - Bathrooms: 2.5
# - House Size: 2,800 sqft
#
# Description: This beautifully updated home in Maple Grove Estates features a modern farmhouse design, a gourmet kitchen with quartz countertops, and a cozy family room with a fireplace. The property also includes a spacious backyard with a deck and garden beds.
#
# Neighborhood Description: Maple Grove Estates is a charming neighborhood with tree-lined streets and a close-knit community feel. Residents have access to parks, schools, and local cafes and shops.
#
# 10.
# - Neighborhood: Hilltop Haven
# - Price: $720,000
# - Bedrooms: 5
# - Bathrooms: 3.5
# - House Size: 3,400 sqft
#
# Description: Located in the serene Hilltop Haven, this spacious home offers vaulted ceilings, a sunlit living room, and a gourmet kitchen with granite countertops. The property includes a private backyard retreat with a covered patio and mature landscaping.
#
# Neighborhood Description: Hilltop Haven is a peaceful neighborhood with panoramic mountain views and a tranquil atmosphere. Residents can enjoy hiking trails, community events, and easy access to nearby schools and recreational facilities.
#
# 1.
# - Neighborhood: Green Hills
# - Price: $650,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 2,800 sqft
#
# Description: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen boasts top-of-the-line appliances and a spacious island. The master suite offers a luxurious retreat with a spa-like bathroom. The backyard oasis includes a covered patio and lush landscaping.
#
# Neighborhood Description: Green Hills is a highly sought-after neighborhood known for its upscale shopping, dining, and entertainment options. Residents enjoy tree-lined streets, parks, and easy access to major highways for convenient commuting.
#
# 2.
# - Neighborhood: East Nashville
# - Price: $475,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 1,900 sqft
#
# Description: This charming craftsman-style home in East Nashville features a cozy living room with a fireplace, a gourmet kitchen with granite countertops, and a spacious master suite with a walk-in closet. The fenced backyard is perfect for outdoor entertaining and gardening.
#
# Neighborhood Description: East Nashville is a vibrant and eclectic neighborhood known for its artsy vibe, trendy boutiques, and diverse dining options. With easy access to downtown Nashville, residents enjoy a mix of urban convenience and neighborhood charm.
#
# 3.
# - Neighborhood: Germantown
# - Price: $800,000
# - Bedrooms: 5
# - Bathrooms: 4
# - House Size: 3,400 sqft
#
# Description: This historic Victorian home in Germantown has been beautifully restored with modern amenities while preserving its original character. Features include hardwood floors, stained glass windows, and a gourmet kitchen. The backyard garden is a peaceful retreat.
#
# Neighborhood Description: Germantown is a historic neighborhood with a mix of charming homes, trendy restaurants, and boutique shops. Residents appreciate the walkable streets, community events, and proximity to downtown Nashville.
#
# 4.
# - Neighborhood: Sylvan Park
# - Price: $550,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 2,100 sqft
#
# Description: This stylish bungalow in Sylvan Park offers an open-concept living space, a designer kitchen with quartz countertops, and a master suite with a spa-like bathroom. The covered front porch and fenced backyard provide additional outdoor living space.
#
# Neighborhood Description: Sylvan Park is a popular neighborhood known for its historic homes, local cafes, and proximity to McCabe Golf Course and Park. Residents enjoy a tight-knit community feel and easy access to downtown Nashville.
#
# 5.
# - Neighborhood: 12 South
# - Price: $725,000
# - Bedrooms: 4
# - Bathrooms: 3.5
# - House Size: 2,600 sqft
#
# Description: This contemporary home in the heart of 12 South features sleek finishes, a gourmet kitchen with stainless steel appliances, and a rooftop deck with stunning views of the city skyline. The master suite includes a walk-in closet and a luxurious bathroom.
#
# Neighborhood Description: 12 South is a trendy and walkable neighborhood with a mix of boutiques, cafes, and restaurants. Residents enjoy a vibrant atmosphere, tree-lined streets, and easy access to Sevier Park and Belmont University.
#
# 6.
# - Neighborhood: Belle Meade
# - Price: $1,200,000
# - Bedrooms: 5
# - Bathrooms: 4.5
# - House Size: 4,000 sqft
#
# Description: This elegant estate in Belle Meade offers luxury living with a grand foyer, formal dining room, gourmet kitchen, and a spacious family room with a fireplace. The outdoor living space includes a covered patio, swimming pool, and beautifully landscaped gardens.
#
# Neighborhood Description: Belle Meade is an exclusive and upscale neighborhood known for its stately homes, country club, and horse farms. Residents enjoy a peaceful setting with easy access to premier shopping, dining, and entertainment options.
#
# 7.
# - Neighborhood: Hillsboro Village
# - Price: $600,000
# - Bedrooms: 4
# - Bathrooms: 2.5
# - House Size: 2,300 sqft
#
# Description: This charming cottage in Hillsboro Village features a cozy living room, a renovated kitchen with quartz countertops, and a master suite with a private balcony. The fenced backyard offers a tranquil escape in the heart of the city.
#
# Neighborhood Description: Hillsboro Village is a historic and walkable neighborhood with a mix of shops, cafes, and theaters. Residents appreciate the neighborhood's bohemian vibe, proximity to Vanderbilt University, and easy access to downtown Nashville.
#
# 8.
# - Neighborhood: West End
# - Price: $950,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 3,000 sqft
#
# Description: This contemporary townhome in West End features a sleek design, high-end finishes, and a gourmet kitchen with a large island. The spacious living area is perfect for entertaining, and the rooftop terrace offers panoramic views of the city.
#
# Neighborhood Description: West End is a vibrant and diverse neighborhood with a mix of historic homes, modern developments, and cultural attractions. Residents enjoy convenient access to Centennial Park, the Parthenon, and a variety of dining and entertainment options.
#
# 9.
# - Neighborhood: The Gulch
# - Price: $850,000
# - Bedrooms: 2
# - Bathrooms: 2.5
# - House Size: 2,200 sqft
#
# Description: This luxury condo in The Gulch offers a sophisticated urban living experience with high ceilings, floor-to-ceiling windows, and a chef's kitchen with top-of-the-line appliances. The building amenities include a fitness center, rooftop pool, and concierge services.
#
# Neighborhood Description: The Gulch is a trendy and upscale neighborhood known for its high-rise condos, boutique shops, and renowned restaurants. Residents enjoy a vibrant nightlife scene, proximity to downtown Nashville, and easy access to public transportation.
#
# 10.
# - Neighborhood: Edgehill
# - Price: $500,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 1,800 sqft
#
# Description: This newly renovated home in Edgehill features an open floor plan, hardwood floors, and a modern kitchen with quartz countertops. The master suite includes a walk-in closet and a spa-like bathroom. The backyard patio is ideal for outdoor gatherings.
#
# Neighborhood Description: Edgehill is a rapidly developing neighborhood with a mix of historic homes, new construction, and local businesses. Residents appreciate the sense of community, nearby parks, and easy access to downtown Nashville and Music Row.
#
# - Neighborhood: Green Hills
# - Price: $750,000
# - Bedrooms: 3
# - Bathrooms: 2.5
# - House Size: 2,200 sqft
#
# Description: This charming home in Green Hills features a modern open floor plan, high ceilings, and a gourmet kitchen with stainless steel appliances. The master suite boasts a luxurious spa-like bathroom. The backyard oasis is perfect for entertaining with a deck and lush landscaping.
#
# Neighborhood Description: Green Hills is a sought-after neighborhood known for its upscale shopping, dining, and proximity to parks. Residents enjoy a vibrant community with excellent schools and easy access to major highways.
#
# - Neighborhood: Historic Germantown
# - Price: $600,000
# - Bedrooms: 2
# - Bathrooms: 2
# - House Size: 1,800 sqft
#
# Description: This historic townhouse in Germantown has been beautifully renovated while preserving its original character. Features include exposed brick walls, hardwood floors, and a private courtyard. The gourmet kitchen is a chef's dream.
#
# Neighborhood Description: Historic Germantown is a trendy neighborhood with a mix of historic charm and modern amenities. Enjoy local cafes, galleries, and boutiques within walking distance. Easy access to downtown and public transportation.
#
# - Neighborhood: Sylvan Park
# - Price: $500,000
# - Bedrooms: 4
# - Bathrooms: 3
# - House Size: 2,500 sqft
#
# Description: This contemporary home in Sylvan Park offers a spacious layout, designer finishes, and a rooftop deck with stunning views. The sleek kitchen features quartz countertops and a large island. The master suite includes a walk-in closet and spa-like bathroom.
#
# Neighborhood Description: Sylvan Park is a vibrant neighborhood with a mix of historic homes and new construction. Enjoy local eateries, coffee shops, and parks. Close to the Greenway for outdoor activities and easy access to downtown.
#
# - Neighborhood: 12 South
# - Price: $850,000
# - Bedrooms: 4
# - Bathrooms: 3.5
# - House Size: 2,800 sqft
#
# Description: This luxurious home in 12 South boasts custom finishes, a gourmet kitchen, and a private backyard oasis with a covered patio and fire pit. The spacious master suite features a soaking tub and walk-in shower. Perfect for modern living and entertaining.
#
# Neighborhood Description: 12 South is a trendy neighborhood known for its eclectic mix of shops, restaurants, and entertainment options. Experience a lively atmosphere with a strong sense of community. Easy access to Belmont University and downtown Nashville.
#
# - Neighborhood: East Nashville
# - Price: $400,000
# - Bedrooms: 3
# - Bathrooms: 2
# - House Size: 1,600 sqft
#
# Description: This stylish bungalow in East Nashville features an open concept layout, hardwood floors, and a designer kitchen with quartz countertops. The fenced backyard offers a private retreat with a deck and mature trees.
#
# Neighborhood Description: East Nashville is a hip and eclectic neighborhood with a thriving arts and music scene. Enjoy local breweries, restaurants, and boutique shops. Close to Shelby Park for outdoor recreation and just a short drive to downtown.

# %%
import pandas as pd
import re

# %%
# Input text

# Split the text into individual property entries
entries = re.split(r'\d+\.\s+', listings.strip())[1:]

# Define a function to extract property details
def extract_details(entry):
    details = {}
    details['Neighborhood'] = re.search(r'- Neighborhood: (.+)', entry).group(1).strip()
    details['Price'] = re.search(r'- Price: (.+)', entry).group(1).strip()
    details['Bedrooms'] = re.search(r'- Bedrooms: (.+)', entry).group(1).strip()
    details['Bathrooms'] = re.search(r'- Bathrooms: (.+)', entry).group(1).strip()
    details['House Size'] = re.search(r'- House Size: (.+)', entry).group(1).strip()
    details['Description'] = re.search(r'Description:\s*(.+?)\n\n', entry, re.DOTALL).group(1).strip()
    details['Neighborhood Description'] = re.search(r'Neighborhood Description:\s*(.+)', entry, re.DOTALL).group(1).strip()
    return details

# Extract details from each entry and create a DataFrame
data = [extract_details(entry) for entry in entries]
df = pd.DataFrame(data)

# Display the DataFrame
df.head()
# Out:
#      Neighborhood       Price Bedrooms Bathrooms  House Size  \
# 0     Green Hills    $750,000        4         3  2,500 sqft
# 1        Downtown  $1,200,000        3       2.5  2,000 sqft
# 2     Belle Meade  $1,500,000        5       4.5  4,000 sqft
# 3  East Nashville    $500,000        2         2  1,200 sqft
# 4     Sylvan Park    $600,000        3       2.5  1,800 sqft
#
#                                          Description  \
# 0  This stunning modern home in Green Hills featu...
# 1  Live in luxury in this sleek downtown condo wi...
# 2  This exquisite estate in Belle Meade exudes el...
# 3  Embrace the eclectic charm of East Nashville i...
# 4  This charming cottage in Sylvan Park offers a ...
#
#                             Neighborhood Description
# 0  Green Hills is a highly sought-after neighborh...
# 1  Downtown is the heart of the city, offering a ...
# 2  Belle Meade is a prestigious neighborhood know...
# 3  East Nashville is a hip and diverse neighborho...
# 4  Sylvan Park is a family-friendly neighborhood ...

# %%
# Convert numeric columns to appropriate types
df['Price'] = df['Price'].str.replace('$', '').str.replace(',', '').astype(float)
df['Bedrooms'] = df['Bedrooms'].astype(int)
df['Bathrooms'] = df['Bathrooms'].astype(float)
df['House Size'] = df['House Size'].str.replace(' sqft', '').str.replace(',', '').astype(int)

# Reorder columns if desired
column_order = ['Neighborhood', 'Price', 'Bedrooms', 'Bathrooms', 'House Size', 'Description', 'Neighborhood Description']
df = df[column_order]
df.columns = ['neighborhood','price','bedrooms','bathrooms','house_size','description','neighborhood_description']
df
# Out:
#              neighborhood      price  bedrooms  bathrooms  house_size  \
# 0             Green Hills   750000.0         4        3.0        2500
# 1                Downtown  1200000.0         3        2.5        2000
# 2             Belle Meade  1500000.0         5        4.5        4000
# 3          East Nashville   500000.0         2        2.0        1200
# 4             Sylvan Park   600000.0         3        2.5        1800
# 5              Germantown   850000.0         4        3.0        2300
# 6                12 South   700000.0         3        2.0        1600
# 7       Hillsboro Village   950000.0         4        3.5        2800
# 8                West End  1100000.0         5        4.0        3500
# 9       Wedgewood-Houston   550000.0         3        2.5        1700
# 10           Willow Creek   450000.0         3        2.5        2100
# 11      Oak Ridge Estates   650000.0         4        3.0        3500
# 12     Riverfront Heights   800000.0         5        4.5        4200
# 13  Mountain View Estates  1200000.0         6        5.0        5000
# 14       Lakeside Retreat   550000.0         3        2.0        2300
# 15           Sunset Ridge   700000.0         4        3.5        3800
# 16      Pinehurst Meadows   480000.0         3        2.0        2100
# 17            Harbor View   950000.0         4        3.5        3600
# 18    Maple Grove Estates   580000.0         4        2.5        2800
# 19          Hilltop Haven   720000.0         5        3.5        3400
# 20            Green Hills   650000.0         4        3.0        2800
# 21         East Nashville   475000.0         3        2.5        1900
# 22             Germantown   800000.0         5        4.0        3400
# 23            Sylvan Park   550000.0         3        2.0        2100
# 24               12 South   725000.0         4        3.5        2600
# 25            Belle Meade  1200000.0         5        4.5        4000
# 26      Hillsboro Village   600000.0         4        2.5        2300
# 27               West End   950000.0         4        3.0        3000
# 28              The Gulch   850000.0         2        2.5        2200
# 29               Edgehill   500000.0         3        2.0        1800
#
#                                           description  \
# 0   This stunning modern home in Green Hills featu...
# 1   Live in luxury in this sleek downtown condo wi...
# 2   This exquisite estate in Belle Meade exudes el...
# 3   Embrace the eclectic charm of East Nashville i...
# 4   This charming cottage in Sylvan Park offers a ...
# 5   Discover urban living at its finest in this co...
# 6   Live in the heart of the trendy 12 South neigh...
# 7   Experience upscale living in this custom-built...
# 8   This elegant home in West End features a grand...
# 9   Modern living awaits in this sleek townhome in...
# 10  This charming home in Willow Creek features a ...
# 11  Nestled in the prestigious Oak Ridge Estates, ...
# 12  This stunning riverfront property features pan...
# 13  Situated in the prestigious Mountain View Esta...
# 14  This lakeside retreat features a cozy cabin-st...
# 15  Perched on a hill in Sunset Ridge, this contem...
# 16  This charming ranch-style home in Pinehurst Me...
# 17  Overlooking the harbor, this elegant home in H...
# 18  This beautifully updated home in Maple Grove E...
# 19  Located in the serene Hilltop Haven, this spac...
# 20  This stunning modern home in Green Hills featu...
# 21  This charming craftsman-style home in East Nas...
# 22  This historic Victorian home in Germantown has...
# 23  This stylish bungalow in Sylvan Park offers an...
# 24  This contemporary home in the heart of 12 Sout...
# 25  This elegant estate in Belle Meade offers luxu...
# 26  This charming cottage in Hillsboro Village fea...
# 27  This contemporary townhome in West End feature...
# 28  This luxury condo in The Gulch offers a sophis...
# 29  This newly renovated home in Edgehill features...
#
#                              neighborhood_description
# 0   Green Hills is a highly sought-after neighborh...
# 1   Downtown is the heart of the city, offering a ...
# 2   Belle Meade is a prestigious neighborhood know...
# 3   East Nashville is a hip and diverse neighborho...
# 4   Sylvan Park is a family-friendly neighborhood ...
# 5   Germantown is a historic neighborhood with a m...
# 6   12 South is a popular neighborhood known for i...
# 7   Hillsboro Village is a vibrant neighborhood wi...
# 8   West End is a prestigious neighborhood known f...
# 9   Wedgewood-Houston is a rapidly growing neighbo...
# 10  Willow Creek is a family-friendly neighborhood...
# 11  Oak Ridge Estates offers a tranquil setting wi...
# 12  Riverfront Heights is an exclusive enclave kno...
# 13  Mountain View Estates is an upscale community ...
# 14  Lakeside Retreat offers a peaceful escape from...
# 15  Sunset Ridge is a sought-after neighborhood kn...
# 16  Pinehurst Meadows is a quiet neighborhood with...
# 17  Harbor View is a prestigious waterfront commun...
# 18  Maple Grove Estates is a charming neighborhood...
# 19  Hilltop Haven is a peaceful neighborhood with ...
# 20  Green Hills is a highly sought-after neighborh...
# 21  East Nashville is a vibrant and eclectic neigh...
# 22  Germantown is a historic neighborhood with a m...
# 23  Sylvan Park is a popular neighborhood known fo...
# 24  12 South is a trendy and walkable neighborhood...
# 25  Belle Meade is an exclusive and upscale neighb...
# 26  Hillsboro Village is a historic and walkable n...
# 27  West End is a vibrant and diverse neighborhood...
# 28  The Gulch is a trendy and upscale neighborhood...
# 29  Edgehill is a rapidly developing neighborhood ...

# %%
df.to_csv('home.csv')

# %% [markdown]
# # Step3: Storing listings in a vector database

# %%
# Define OpenAI API key 
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
loader = CSVLoader(file_path='./home.csv')
docs = loader.load()

# %%
model_name = 'gpt-3.5-turbo'
llm = OpenAI(model_name=model_name, temperature=0, max_tokens=2000)
# Out:
# /home/student/.local/lib/python3.10/site-packages/langchain_community/llms/openai.py:254: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# /home/student/.local/lib/python3.10/site-packages/langchain_community/llms/openai.py:1075: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(

# %%
import pandas as pd
from langchain.schema import Document
df = pd.read_csv('./home.csv')
documents = []
for index, row in df.iterrows():
    documents.append(Document(page_content=row['description'], metadata={'id': str(index)}))

# %%
splitter = CharacterTextSplitter(chunk_size= 300, chunk_overlap=100)
split_docs = splitter.split_documents(docs)
print(f"Split {len(documents)} documents into {len(split_docs)} chunks.")
# Out:
# Created a chunk of size 604, which is longer than the specified 300
# Created a chunk of size 394, which is longer than the specified 300
# Created a chunk of size 354, which is longer than the specified 300
# Created a chunk of size 372, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Split 30 documents into 40 chunks.

# %%
#check whether data is loaded correctly
if split_docs:
    document = split_docs[10]
    print(document.page_content)
    print(document.metadata)
# Out:
# : 10
# neighborhood: Willow Creek
# price: 450000.0
# bedrooms: 3
# bathrooms: 2.5
# house_size: 2100
# description: This charming home in Willow Creek features a modern open concept design with a spacious living area, gourmet kitchen, and a cozy backyard patio perfect for entertaining. Energy-efficient appliances and smart home features make this property both stylish and eco-friendly.
# neighborhood_description: Willow Creek is a family-friendly neighborhood known for its top-rated schools, parks, and walking trails. Residents enjoy easy access to shopping centers, restaurants, and public transportation options.
# {'source': './home.csv', 'row': 10}

# %%
from langchain_community.document_loaders import CSVLoader
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma


# Load the document, split it into chunks, embed each chunk and load it into the vector store.
raw_documents = CSVLoader('./home.csv').load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
documents = text_splitter.split_documents(raw_documents)

# %%
db = Chroma.from_documents(documents, OpenAIEmbeddings())

# %%
print(dir(db))
# Out:
# ['_Chroma__ensure_collection', '_Chroma__query_collection', '_LANGCHAIN_DEFAULT_COLLECTION_NAME', '__abstractmethods__', '__annotations__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_asimilarity_search_with_relevance_scores', '_chroma_collection', '_client', '_client_settings', '_collection', '_collection_metadata', '_collection_name', '_cosine_relevance_score_fn', '_embedding_function', '_euclidean_relevance_score_fn', '_get_retriever_tags', '_max_inner_product_relevance_score_fn', '_persist_directory', '_select_relevance_score_fn', '_similarity_search_with_relevance_scores', 'aadd_documents', 'aadd_texts', 'add_documents', 'add_images', 'add_texts', 'adelete', 'afrom_documents', 'afrom_texts', 'aget_by_ids', 'amax_marginal_relevance_search', 'amax_marginal_relevance_search_by_vector', 'as_retriever', 'asearch', 'asimilarity_search', 'asimilarity_search_by_vector', 'asimilarity_search_with_relevance_scores', 'asimilarity_search_with_score', 'delete', 'delete_collection', 'embeddings', 'encode_image', 'from_documents', 'from_texts', 'get', 'get_by_ids', 'max_marginal_relevance_search', 'max_marginal_relevance_search_by_vector', 'override_relevance_score_fn', 'reset_collection', 'search', 'similarity_search', 'similarity_search_by_vector', 'similarity_search_by_vector_with_relevance_scores', 'similarity_search_with_relevance_scores', 'similarity_search_with_score', 'update_document', 'update_documents']

# %%
# Step 4: Building the User Preference Interface
questions = [
    "How big do you want your house to be?",
    "What are 3 most important things for you in choosing this property?",
    "Which amenities would you like?",
    "Which transportation options are important to you?",
    "How urban do you want your neighborhood to be?",
]

answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters.",
]

buyer_preferences = {
    "house_size": answers[0],
    "important_factors": answers[1].split(", "),
    "amenities": answers[2].split(", "),
    "transportation": answers[3].split(", "),
    "neighborhood_urbanity": answers[4],
}

# %%
buyer_preferences
# Out:
# {'house_size': 'A comfortable three-bedroom house with a spacious kitchen and a cozy living room.',
#  'important_factors': ['A quiet neighborhood',
#   'good local schools',
#   'and convenient shopping options.'],
#  'amenities': ['A backyard for gardening',
#   'a two-car garage',
#   'and a modern',
#   'energy-efficient heating system.'],
#  'transportation': ['Easy access to a reliable bus line',
#   'proximity to a major highway',
#   'and bike-friendly roads.'],
#  'neighborhood_urbanity': 'A balance between suburban tranquility and access to urban amenities like restaurants and theaters.'}

# %% [markdown]
# # Step 5: Searching Based on Preferences

# %%
joined_string = ''.join(
    str(item) if not isinstance(item, list) else ''.join(str(i) for i in item)
    for item in buyer_preferences.values()
)

print(joined_string)
# Out:
# A comfortable three-bedroom house with a spacious kitchen and a cozy living room.A quiet neighborhoodgood local schoolsand convenient shopping options.A backyard for gardeninga two-car garageand a modernenergy-efficient heating system.Easy access to a reliable bus lineproximity to a major highwayand bike-friendly roads.A balance between suburban tranquility and access to urban amenities like restaurants and theaters.

# %%
similar_docs = db.similarity_search(joined_string, k=5)
similar_docs
# Out:
# [Document(metadata={'row': 0, 'source': './home.csv'}, page_content=': 0\nneighborhood: Green Hills\nprice: 750000.0\nbedrooms: 4\nbathrooms: 3.0\nhouse_size: 2500\ndescription: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen is equipped with stainless steel appliances and quartz countertops. The master suite boasts a luxurious bathroom with a soaking tub and walk-in shower. Enjoy the spacious backyard perfect for entertaining.\nneighborhood_description: Green Hills is a highly sought-after neighborhood known for its upscale shops, restaurants, and top-rated schools. Residents enjoy easy access to parks, walking trails, and convenient transportation options.'),
#  Document(metadata={'row': 20, 'source': './home.csv'}, page_content=': 20\nneighborhood: Green Hills\nprice: 650000.0\nbedrooms: 4\nbathrooms: 3.0\nhouse_size: 2800\ndescription: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen boasts top-of-the-line appliances and a spacious island. The master suite offers a luxurious retreat with a spa-like bathroom. The backyard oasis includes a covered patio and lush landscaping.\nneighborhood_description: Green Hills is a highly sought-after neighborhood known for its upscale shopping, dining, and entertainment options. Residents enjoy tree-lined streets, parks, and easy access to major highways for convenient commuting.'),
#  Document(metadata={'row': 10, 'source': './home.csv'}, page_content=': 10\nneighborhood: Willow Creek\nprice: 450000.0\nbedrooms: 3\nbathrooms: 2.5\nhouse_size: 2100\ndescription: This charming home in Willow Creek features a modern open concept design with a spacious living area, gourmet kitchen, and a cozy backyard patio perfect for entertaining. Energy-efficient appliances and smart home features make this property both stylish and eco-friendly.\nneighborhood_description: Willow Creek is a family-friendly neighborhood known for its top-rated schools, parks, and walking trails. Residents enjoy easy access to shopping centers, restaurants, and public transportation options.'),
#  Document(metadata={'row': 4, 'source': './home.csv'}, page_content=': 4\nneighborhood: Sylvan Park\nprice: 600000.0\nbedrooms: 3\nbathrooms: 2.5\nhouse_size: 1800\ndescription: This charming cottage in Sylvan Park offers a blend of modern updates and historic character. The home features a renovated kitchen, hardwood floors, and a cozy fireplace in the living room. The fenced backyard is perfect for outdoor gatherings.\nneighborhood_description: Sylvan Park is a family-friendly neighborhood with tree-lined streets, parks, and a bustling commercial district with cafes, shops, and restaurants. The area provides a laid-back atmosphere with easy access to downtown Nashville.'),
#  Document(metadata={'row': 5, 'source': './home.csv'}, page_content=": 5\nneighborhood: Germantown\nprice: 850000.0\nbedrooms: 4\nbathrooms: 3.0\nhouse_size: 2300\ndescription: Discover urban living at its finest in this contemporary townhome in Germantown. The home features a rooftop deck with skyline views, a gourmet kitchen with custom cabinetry, and a luxurious master suite with a spa-like bathroom. Enjoy the convenience of a two-car garage.\nneighborhood_description: Germantown is a historic neighborhood with a mix of old-world charm and modern amenities. Residents appreciate the neighborhood's walkability, proximity to boutique shops and eateries, and easy access to green spaces and cultural venues.")]

# %%
def parse_document_content(content):
    # Define patterns for each field
    patterns = {
        'description': r'description:\s*(.*?)(?=\n|$)',
        'neighborhood_description': r'neighborhood_description:\s*(.*?)(?=\n|$)',
        'price': r'price:\s*([\d.,]+)',
        'bedrooms': r'bedrooms:\s*(\d+)',
        'bathrooms': r'bathrooms:\s*([\d.]+)',
        'house_size': r'house_size:\s*([\d.]+)'
    }
    
    # Extract data using regex patterns
    extracted_data = {}
    for field, pattern in patterns.items():
        match = re.search(pattern, content, re.DOTALL)
        extracted_data[field] = match.group(1).strip() if match else 'Not Available'
    
    return extracted_data

# Function to format the extracted data
def format_document(document):
    content = document.page_content
    data = parse_document_content(content)
    
    formatted_string = (
        f"Description: {data['description']}\n"
        f"Neighborhood Description: {data['neighborhood_description']}\n"
        f"Price: {data['price']}\n"
        f"Bedrooms: {data['bedrooms']}\n"
        f"Bathrooms: {data['bathrooms']}\n"
        f"House Size (sqft): {data['house_size']}"
    )
    
    return formatted_string

# Apply formatting to each document and print results
for doc in similar_docs:
    print(format_document(doc))
    print()  # Add a newline for better readability
# Out:
# Description: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen is equipped with stainless steel appliances and quartz countertops. The master suite boasts a luxurious bathroom with a soaking tub and walk-in shower. Enjoy the spacious backyard perfect for entertaining.
# Neighborhood Description: Green Hills is a highly sought-after neighborhood known for its upscale shops, restaurants, and top-rated schools. Residents enjoy easy access to parks, walking trails, and convenient transportation options.
# Price: 750000.0
# Bedrooms: 4
# Bathrooms: 3.0
# House Size (sqft): 2500
#
# Description: This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen boasts top-of-the-line appliances and a spacious island. The master suite offers a luxurious retreat with a spa-like bathroom. The backyard oasis includes a covered patio and lush landscaping.
# Neighborhood Description: Green Hills is a highly sought-after neighborhood known for its upscale shopping, dining, and entertainment options. Residents enjoy tree-lined streets, parks, and easy access to major highways for convenient commuting.
# Price: 650000.0
# Bedrooms: 4
# Bathrooms: 3.0
# House Size (sqft): 2800
#
# Description: This charming home in Willow Creek features a modern open concept design with a spacious living area, gourmet kitchen, and a cozy backyard patio perfect for entertaining. Energy-efficient appliances and smart home features make this property both stylish and eco-friendly.
# Neighborhood Description: Willow Creek is a family-friendly neighborhood known for its top-rated schools, parks, and walking trails. Residents enjoy easy access to shopping centers, restaurants, and public transportation options.
# Price: 450000.0
# Bedrooms: 3
# Bathrooms: 2.5
# House Size (sqft): 2100
#
# Description: This charming cottage in Sylvan Park offers a blend of modern updates and historic character. The home features a renovated kitchen, hardwood floors, and a cozy fireplace in the living room. The fenced backyard is perfect for outdoor gatherings.
# Neighborhood Description: Sylvan Park is a family-friendly neighborhood with tree-lined streets, parks, and a bustling commercial district with cafes, shops, and restaurants. The area provides a laid-back atmosphere with easy access to downtown Nashville.
# Price: 600000.0
# Bedrooms: 3
# Bathrooms: 2.5
# House Size (sqft): 1800
#
# Description: Discover urban living at its finest in this contemporary townhome in Germantown. The home features a rooftop deck with skyline views, a gourmet kitchen with custom cabinetry, and a luxurious master suite with a spa-like bathroom. Enjoy the convenience of a two-car garage.
# Neighborhood Description: Germantown is a historic neighborhood with a mix of old-world charm and modern amenities. Residents appreciate the neighborhood's walkability, proximity to boutique shops and eateries, and easy access to green spaces and cultural venues.
# Price: 850000.0
# Bedrooms: 4
# Bathrooms: 3.0
# House Size (sqft): 2300

# %% [markdown]
# # Step 6: Personalizing Listing Descriptions

# %%
import openai
openai.api_key = api_key = ''
def generate_personalized_description(property_details, buyer_preferences):
    prompt = f"""
    You are a skilled real estate agent. Given the following property details and buyer preferences, craft a personalized listing description that emphasizes features matching the buyer's interests. Ensure that factual details are preserved.

    **Property Details:**
    Description: {property_details['description']}
    Neighborhood Description: {property_details['neighborhood_description']}
    Price: {property_details['price']}
    Bedrooms: {property_details['bedrooms']}
    Bathrooms: {property_details['bathrooms']}
    House Size (sqft): {property_details['house_size']}

    **Buyer Preferences:**
    {buyer_preferences}

    **Personalized Listing Description:**
    """
    
    response = openai.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a real estate agent.For each retrieved listing, tailor it to resonate with the buyers' specific preferences. This invovles subtly emphasizing aspects of the property that align with what the buyer is looking for"},
                    {"role": "user", "content": buyer_preferences}
                ],
                temperature=0.5,  # Adjust for creativity level
                max_tokens=1500,
    )
    return response.choices[0].message.content

# %%
property_details = {
    'description': 'This stunning modern home in Green Hills features an open floor plan, high ceilings, and large windows that flood the space with natural light. The kitchen is equipped with stainless steel appliances and quartz countertops. The master suite boasts a luxurious bathroom with a soaking tub and walk-in shower. Enjoy the spacious backyard perfect for entertaining.',
    'neighborhood_description': 'Green Hills is a highly sought-after neighborhood known for its upscale shops, restaurants, and top-rated schools. Residents enjoy easy access to parks, walking trails, and convenient transportation options.',
    'price': '750000.0',
    'bedrooms': '4',
    'bathrooms': '3.0',
    'house_size': '2500'
}

buyer_preferences = "Interested in modern kitchens and spacious backyards. Prefers neighborhoods with top-rated schools and easy access to parks. Budget: up to $800,000."

# Generate the personalized description
personalized_description = generate_personalized_description(property_details, buyer_preferences)

print(personalized_description)
# Out:
# 🏡 **Modern Home with Spacious Backyard in Family-Friendly Neighborhood**
#
# Welcome home to this stunning property located in a sought-after neighborhood known for its top-rated schools and proximity to parks.
#
# As you step inside, you'll be greeted by a beautifully renovated modern kitchen featuring sleek cabinetry, stainless steel appliances, and quartz countertops. The open layout is perfect for entertaining guests or simply enjoying family meals together.
#
# Step outside to your expansive backyard, ideal for hosting summer barbecues, gardening, or simply relaxing in the sunshine. With plenty of space for kids to play and pets to roam, this backyard oasis is a rare find in the area.
#
# This home is situated in a family-friendly community known for its excellent schools and safe streets. Enjoy easy access to nearby parks, perfect for morning jogs, picnics, or weekend outings with the family.
#
# Priced at $800,000, this property offers the perfect blend of modern living, outdoor space, and a prime location. Don't miss out on the opportunity to make this your dream home! Contact us today to schedule a private tour.
